# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd
import numpy as np
import gurobipy as grb
from itertools import combinations
from collections import defaultdict
import networkx as nx
import matplotlib.pyplot as plt

# %%
# filepath = r"E:\2024 Fall Academic\Optimization Models and Methods\IEOR4004_Project2\airports.csv"
airports_df = pd.read_csv("airports.csv")
airports_df = airports_df.drop(columns=['Unnamed: 0']) #drop the original index
airports_df = airports_df.set_index('airport_code')
airports_df.head()
# Out:
#                     country                                  airport_name  \
# airport_code
# JFK                     USA         John F. Kennedy International Airport
# LAX                     USA             Los Angeles International Airport
# ABJ           Côte d'Ivoire  Félix Houphouët Boigny International Airport
# SGN                 Vietnam            Tan Son Nhat International Airport
# LOS                 Nigeria        Murtala Muhammed International Airport
#
#                  latitude     longitude  latitude_deg  longitude_deg
# airport_code
# JFK           40.639751°N   73.778925°W     40.639751     -73.778925
# LAX           33.942536°N  118.408075°W     33.942536    -118.408075
# ABJ            5.261417°N    3.925778°W      5.261417      -3.925778
# SGN           10.818797°N  106.651856°E     10.818797     106.651856
# LOS            6.577369°N    3.321156°E      6.577369       3.321156

# %%
#Calculte the distance matrices and create the dataframe
airport_codes = airports_df.index.tolist()

#Create the null datadrame
n = len(airport_codes)
distance_matrix_df = pd.DataFrame(
    data=[[0]*n for _ in range(n)],  # Initialize with zeros or any default value
    index=airport_codes,  # Row labels
    columns=airport_codes, # Column labels
    dtype = float
)

# Earth's radius in kilometers
R = 6371 

# Haversine formula function
def haversine(lat1, lon1, lat2, lon2):
    # Convert latitude and longitude from degrees to radians
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    # Calculate the differences in latitude and longitude
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    # Apply the Haversine formula
    a = np.sin(dlat / 2) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2) ** 2
    c = 2 * np.arcsin(np.sqrt(a))
    return R * c  # Return the distance

# Calculate pairwise distances
for i in airport_codes:
    for j in airport_codes:
        if i != j:  # Exclude the same airport (distance to itself)
            dist = haversine(
                airports_df.loc[i, 'latitude_deg'],
                airports_df.loc[i, 'longitude_deg'],
                airports_df.loc[j, 'latitude_deg'],
                airports_df.loc[j, 'longitude_deg']
            )
            distance_matrix_df.loc[i,j]=dist

distance_matrix_df.head()
# Out:
#               JFK           LAX           ABJ           SGN           LOS  \
# JFK      0.000000   3974.199962   7932.445338  14292.985735   8444.433260
# LAX   3974.199962      0.000000  11889.687339  13130.434231  12418.516006
# ABJ   7932.445338  11889.687339      0.000000  12126.944839    814.749463
# SGN  14292.985735  13130.434231  12126.944839      0.000000  11313.043117
# LOS   8444.433260  12418.516006    814.749463  11313.043117      0.000000
#
#               LUN           DAR           KGL           PAP           HRE  \
# JFK  12131.540012  12436.913035  11321.564031   2457.096611  12531.082351
# LAX  16105.679750  16227.358769  15188.259583   4858.775364  16504.654999
# ABJ   4237.909109   4972.815263   3868.202352   7543.453633   4626.965032
# SGN   9086.282000   7719.302576   8577.983776  16744.101212   8885.163278
# LOS   3687.902467   4252.500718   3124.810548   8262.738318   4088.871310
#
#      ...           KRT           BKO           GUA           LFW  \
# JFK  ...  10201.892576   7071.942699   3320.742820   8300.223022
# LAX  ...  13706.897513  11043.455234   3531.499861  12273.503697
# ABJ  ...   4143.341574    921.426718   9495.948931    581.903836
# SGN  ...   8001.758553  12343.071362  16614.619959  11545.906441
# LOS  ...   3338.756991   1401.592385  10234.972169    232.924648
#
#               KBL           ROB           OUA           CKY           TIP  \
# JFK  10834.702090   7328.032681   7626.340835   6813.588504   7485.275620
# LAX  12356.043086  11256.835565  11598.556142  10748.343709  11044.420574
# ABJ   8133.811652    720.294920    831.907983   1170.621886   3524.986505
# SGN   4616.972357  12790.960763  11676.366162  13030.605375   9682.939776
# LOS   7391.753467   1512.502886    832.630398   1893.444356   3074.065004
#
#               BZE
# JFK   2921.668991
# LAX   3502.779599
# ABJ   9237.462726
# SGN  16459.320758
# LOS   9959.216612
#
# [5 rows x 45 columns]

# %%
#Cteate the distance matrices dictionary
distance_array = distance_matrix_df.to_numpy()
distance_dict = {}
for i in range(len(airport_codes)):
    for j in range(len(airport_codes)):
            distance_dict [(airport_codes[i], airport_codes[j])] = distance_array[i,j]

# %% [markdown]
# ## Problem 1: The Problem of Optimizing Shipment

# %%
model_pb1 = grb.Model("Problem 1")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-09

# %%
#Define the binary variable x between each pair of airports to decide whether the arcs between exists
x_vars = model_pb1.addVars(
    airport_codes,
    airport_codes,
    lb=0,             
    vtype=grb.GRB.BINARY,  
    name="x"          
)

# %%
#Each node is arrived and departed only once (except the starting and the ending point)
for i in airport_codes:
    departure_sum = grb.quicksum(x_vars[(i,j)] for j in airport_codes if i != j)
    arrival_sum = grb.quicksum(x_vars[(j,i)] for j in airport_codes if i != j)
    
    if i == "JFK":
        model_pb1.addConstr(departure_sum == 1, name = "JFK: departed only once")
        model_pb1.addConstr(arrival_sum == 0, name = "JFK: never arrived")
    elif i == "LAX":
        model_pb1.addConstr(departure_sum == 0, name = "LAX: never departed")
        model_pb1.addConstr(arrival_sum == 1, name = "LAX: arrived only once")
    else:
        model_pb1.addConstr(departure_sum == 1, name = "departed only once")
        model_pb1.addConstr(arrival_sum == 1, name = "arrived only once")

# Route x_ii == 0
for i in airport_codes:
    model_pb1.addConstr((x_vars[(i,i)]) == 0)

# %%
#Set objective
total_distance = grb.quicksum((x_vars[(i,j)] * distance_dict[i,j]) 
                     for i in airport_codes
                     for j in airport_codes 
                    )
model_pb1.setObjective(total_distance, grb.GRB.MINIMIZE)
model_pb1.update()

# %%
print(f"Number of constraints: {len(model_pb1.getConstrs())}")
print(f"Number of variables: {len(model_pb1.getVars())}")
# Out:
# Number of constraints: 135
# Number of variables: 2025

# %%
# Initially optimize the model
model_pb1.optimize()

# Define a function to detect subtours
def find_subtours(solution, n_nodes, airport_codes=airport_codes):
    """
    Detect subtours in the solution.
    solution: The current solution used to construct the path graph.
    Returns: A list of subtours, where each subtour is a set of nodes.
    """
    # Build an adjacency list
    graph = defaultdict(list)
    for i in airport_codes:
        for j in airport_codes:
            if solution[i, j] > 0.5:  # Selected paths
                graph[i].append(j)

    # Use Depth First Search (DFS) to find all connected components
    visited = {code: False for code in airport_codes}
    subtours = []

    def dfs(node, current_tour):
        visited[node] = True
        current_tour.append(node)
        for neighbor in graph[node]:
            if not visited[neighbor]:
                dfs(neighbor, current_tour)

    for airport in airport_codes:
        if not visited[airport]:
            current_tour = []
            dfs(airport, current_tour)
            if 2 <= len(current_tour) <= n_nodes - 1:  # Exclude single-node loops and the whole tour
                subtours.append(current_tour)

    return subtours

# Dynamically add subtour elimination constraints
while True:
    # Get the current solution
    solution = model_pb1.getAttr("X", x_vars)

    # Check if there are any subtours
    subtours = find_subtours(solution, n)

    # Termination condition 1: No subtours, optimal solution found
    if not subtours:
        print("Optimal solution found")
        break

    # Add subtour elimination constraints
    for subtour in subtours:
        # Construct subtour constraints
        if len(subtour) > 1:
            model_pb1.addConstr(
                grb.quicksum(
                    x_vars[i, j]
                    for i in subtour for j in subtour if i != j
                ) <= len(subtour) - 1
            )

    # Re-optimize the model
    model_pb1.optimize()

# Output the final path
if model_pb1.status == grb.GRB.OPTIMAL:
    print("Optimal path:")
    for i in airport_codes:
        for j in airport_codes:
            if x_vars[i, j].x > 0.5:
                print(f"Airport {i} -> Airport {j}")
    
    print(f"The minimum distance is {model_pb1.ObjVal:.2f}")
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 135 rows, 2025 columns and 4005 nonzeros
# Model fingerprint: 0x07f90622
# Variable types: 0 continuous, 2025 integer (2025 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 256918.00481
# Presolve removed 47 rows and 132 columns
# Presolve time: 0.01s
# Presolved: 88 rows, 1893 columns, 3786 nonzeros
# Variable types: 0 continuous, 1893 integer (1893 binary)
#
# Root relaxation: objective 3.907571e+04, 72 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    39075.711892 39075.7119  0.00%     -    0s
#
# Explored 1 nodes (72 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 2: 39075.7 256918
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.907571189190e+04, best bound 3.907571189190e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 156 rows, 2025 columns and 4059 nonzeros
# Model fingerprint: 0x62257ea3
# Variable types: 0 continuous, 2025 integer (2025 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R136 by 1.000000000
#
# Found heuristic solution: objective 256918.00481
# Presolve removed 48 rows and 132 columns
# Presolve time: 0.01s
# Presolved: 108 rows, 1893 columns, 3838 nonzeros
# Variable types: 0 continuous, 1893 integer (1893 binary)
#
# Root relaxation: objective 4.693479e+04, 123 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 46934.7877    0   20 256918.005 46934.7877  81.7%     -    0s
# H    0     0                    47954.448749 46934.7877  2.13%     -    0s
# H    0     0                    47791.017333 46934.7877  1.79%     -    0s
# H    0     0                    47550.353632 46934.7877  1.29%     -    0s
#      0     0 46934.7877    0   26 47550.3536 46934.7877  1.29%     -    0s
#      0     0 46934.7877    0   20 47550.3536 46934.7877  1.29%     -    0s
# H    0     0                    47513.031018 46934.7877  1.22%     -    0s
# H    0     0                    47079.421759 46934.7877  0.31%     -    0s
#      0     0 46948.8661    0   26 47079.4218 46948.8661  0.28%     -    0s
#      0     0 46948.8661    0   14 47079.4218 46948.8661  0.28%     -    0s
# H    0     0                    46977.022922 46948.8661  0.06%     -    0s
#      0     0 46963.1214    0   17 46977.0229 46963.1214  0.03%     -    0s
#
# Cutting planes:
#   Mod-K: 4
#
# Explored 1 nodes (282 simplex iterations) in 0.05 seconds (0.03 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 8: 46977 47079.4 47513 ... 256918
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.697702292160e+04, best bound 4.697702292160e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 163 rows, 2025 columns and 4953 nonzeros
# Model fingerprint: 0x9a9c8f4b
# Variable types: 0 continuous, 2025 integer (2025 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R157 by 1.000000000
#
# Found heuristic solution: objective 256918.00481
# Presolve removed 49 rows and 132 columns
# Presolve time: 0.01s
# Presolved: 114 rows, 1893 columns, 4730 nonzeros
# Variable types: 0 continuous, 1893 integer (1893 binary)
#
# Root relaxation: objective 4.717557e+04, 129 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 47175.5749    0   38 256918.005 47175.5749  81.6%     -    0s
# H    0     0                    47302.943496 47175.5749  0.27%     -    0s
# H    0     0                    47200.544658 47175.5749  0.05%     -    0s
#      0     0 47175.5749    0   73 47200.5447 47175.5749  0.05%     -    0s
#
# Cutting planes:
#   Zero half: 2
#
# Explored 1 nodes (139 simplex iterations) in 0.03 seconds (0.02 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 3: 47200.5 47302.9 256918
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.720054465841e+04, best bound 4.720054465841e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 167 rows, 2025 columns and 6051 nonzeros
# Model fingerprint: 0x0e34f56a
# Variable types: 0 continuous, 2025 integer (2025 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R164 by 1.000000000
#
# Found heuristic solution: objective 256918.00481
# Presolve removed 50 rows and 132 columns
# Presolve time: 0.01s
# Presolved: 117 rows, 1893 columns, 5826 nonzeros
# Variable types: 0 continuous, 1893 integer (1893 binary)
#
# Root relaxation: objective 5.112833e+04, 147 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 51128.3321    0   34 256918.005 51128.3321  80.1%     -    0s
# H    0     0                    57191.177326 51128.3321  10.6%     -    0s
# H    0     0                    52687.271983 51128.3321  2.96%     -    0s
# H    0     0                    52170.220536 51128.3321  2.00%     -    0s
#      0     0 51128.3321    0   52 52170.2205 51128.3321  2.00%     -    0s
#      0     0 51128.3321    0   34 52170.2205 51128.3321  2.00%     -    0s
# H    0     0                    52022.115543 51128.3321  1.72%     -    0s
# H    0     0                    51516.299008 51128.3321  0.75%     -    0s
#      0     0 51192.4113    0   56 51516.2990 51192.4113  0.63%     -    0s
#      0     0 51192.4113    0   31 51516.2990 51192.4113  0.63%     -    0s
#      0     0 51192.4113    0   45 51516.2990 51192.4113  0.63%     -    0s
# H    0     0                    51461.425957 51192.4113  0.52%     -    0s
# H    0     0                    51294.198585 51192.4113  0.20%     -    0s
#
# Cutting planes:
#   Gomory: 5
#   Zero half: 6
#
# Explored 1 nodes (405 simplex iterations) in 0.08 seconds (0.05 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 10: 51294.2 51461.4 51516.3 ... 256918
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.129419858476e+04, best bound 5.129419858476e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 178 rows, 2025 columns and 6239 nonzeros
# Model fingerprint: 0x2471f071
# Variable types: 0 continuous, 2025 integer (2025 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R168 by 1.000000000
#
# Found heuristic solution: objective 256918.00481
# Presolve removed 50 rows and 132 columns
# Presolve time: 0.01s
# Presolved: 128 rows, 1893 columns, 6003 nonzeros
# Variable types: 0 continuous, 1893 integer (1893 binary)
#
# Root relaxation: objective 5.137232e+04, 159 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    51372.322404 51372.3224  0.00%     -    0s
#
# Explored 1 nodes (159 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 2: 51372.3 256918
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.137232240443e+04, best bound 5.137232240443e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 181 rows, 2025 columns and 7303 nonzeros
# Model fingerprint: 0x8a05c4c9
# Variable types: 0 continuous, 2025 integer (2025 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R179 by 1.000000000
#
# Found heuristic solution: objective 256918.00481
# Presolve removed 51 rows and 131 columns
# Presolve time: 0.01s
# Presolved: 130 rows, 1894 columns, 6903 nonzeros
# Variable types: 0 continuous, 1894 integer (1893 binary)
#
# Root relaxation: objective 5.170228e+04, 174 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 51702.2831    0   38 256918.005 51702.2831  79.9%     -    0s
# H    0     0                    54048.221612 51702.2831  4.34%     -    0s
# H    0     0                    53886.241680 51702.2831  4.05%     -    0s
#      0     0 51702.2831    0   60 53886.2417 51702.2831  4.05%     -    0s
#      0     0 51702.2831    0   38 53886.2417 51702.2831  4.05%     -    0s
# H    0     0                    51718.063651 51702.2831  0.03%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Zero half: 3
#
# Explored 1 nodes (406 simplex iterations) in 0.07 seconds (0.06 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 4: 51718.1 53886.2 54048.2 256918
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.171806365056e+04, best bound 5.171806365056e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 183 rows, 2025 columns and 8751 nonzeros
# Model fingerprint: 0x56eba7bd
# Variable types: 0 continuous, 2025 integer (2025 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R182 by 1.000000000
#
# Found heuristic solution: objective 256918.00481
# Presolve removed 51 rows and 131 columns
# Presolve time: 0.01s
# Presolved: 132 rows, 1894 columns, 6000 nonzeros
# Variable types: 0 continuous, 1894 integer (1893 binary)
#
# Root relaxation: objective 5.499797e+04, 165 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 54997.9686    0   48 256918.005 54997.9686  78.6%     -    0s
# H    0     0                    59027.628495 54997.9686  6.83%     -    0s
#      0     0 54997.9686    0   56 59027.6285 54997.9686  6.83%     -    0s
#      0     0 54997.9686    0   48 59027.6285 54997.9686  6.83%     -    0s
# H    0     0                    58630.098154 54997.9686  6.19%     -    0s
# H    0     0                    57504.374044 54997.9686  4.36%     -    0s
# H    0     0                    55171.269212 54997.9686  0.31%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Zero half: 6
#
# Explored 1 nodes (418 simplex iterations) in 0.08 seconds (0.07 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 5: 55171.3 57504.4 58630.1 ... 256918
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.517126921177e+04, best bound 5.517126921177e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 188 rows, 2025 columns and 9959 nonzeros
# Model fingerprint: 0xb2585b0a
# Variable types: 0 continuous, 2025 integer (2025 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R184 by 1.000000000
#
# Found heuristic solution: objective 256918.00481
# Presolve removed 53 rows and 132 columns
# Presolve time: 0.01s
# Presolved: 135 rows, 1893 columns, 9627 nonzeros
# Variable types: 0 continuous, 1893 integer (1893 binary)
#
# Root relaxation: objective 5.682849e+04, 180 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    56828.487093 56828.4871  0.00%     -    0s
#
# Explored 1 nodes (180 simplex iterations) in 0.03 seconds (0.04 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 2: 56828.5 256918
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.682848709308e+04, best bound 5.682848709308e+04, gap 0.0000%
# Optimal solution found
# Optimal path:
# Airport JFK -> Airport TIP
# Airport ABJ -> Airport OUA
# Airport SGN -> Airport ADD
# Airport LOS -> Airport COO
# Airport LUN -> Airport HRE
# Airport DAR -> Airport LLW
# Airport KGL -> Airport BJM
# Airport PAP -> Airport BZE
# Airport HRE -> Airport MPM
# Airport ADD -> Airport KRT
# Airport JNB -> Airport GBE
# Airport GEO -> Airport JBQ
# Airport WDH -> Airport LAD
# Airport GBE -> Airport WDH
# Airport MPM -> Airport SHO
# Airport NBO -> Airport DAR
# Airport ALA -> Airport SGN
# Airport EBB -> Airport KGL
# Airport FRU -> Airport ALA
# Airport DSS -> Airport GEO
# Airport COO -> Airport LFW
# Airport MSU -> Airport JNB
# Airport ISB -> Airport FRU
# Airport SHO -> Airport MSU
# Airport ACC -> Airport ABJ
# Airport LAD -> Airport FIH
# Airport BEY -> Airport KBL
# Airport FNA -> Airport CKY
# Airport DLA -> Airport LOS
# Airport JUB -> Airport EBB
# Airport BJM -> Airport NBO
# Airport JBQ -> Airport PAP
# Airport LLW -> Airport LUN
# Airport FIH -> Airport DLA
# Airport KRT -> Airport JUB
# Airport BKO -> Airport ROB
# Airport GUA -> Airport LAX
# Airport LFW -> Airport ACC
# Airport KBL -> Airport ISB
# Airport ROB -> Airport FNA
# Airport OUA -> Airport BKO
# Airport CKY -> Airport DSS
# Airport TIP -> Airport BEY
# Airport BZE -> Airport GUA
# The minimum distance is 56828.49

# %%
# Output the final path and plot the graph
if model_pb1.status == grb.GRB.OPTIMAL:
    print("Optimal path:")

    # Collect the optimal path
    optimal_path = {}
    for i in airport_codes:
        for j in airport_codes:
            if x_vars[i, j].x > 0.5:  # If the path is selected in the optimal solution
                optimal_path[i] = j

    # Output the ordered path
    start = "JFK"  # Assume the starting point is JFK; adjust as needed
    ordered_path = []
    current = start
    while current in optimal_path:
        next_node = optimal_path[current]
        ordered_path.append(f"{current} -> {next_node}")
        current = next_node
        if current == start:  # Stop when the path returns to the starting point
            break

    # Print the ordered path
    ordered_path_str = ", ".join(ordered_path)
    print(ordered_path_str)

    # Use NetworkX to draw the path graph
    G = nx.DiGraph()  # Create a directed graph
    for i in airport_codes:
        G.add_node(i, pos=(airports_df.loc[i, 'longitude_deg'], airports_df.loc[i, 'latitude_deg']))
    G.add_edges_from([(i, j) for i, j in optimal_path.items()])

    # Use circular layout for visualization
    # pos = nx.circular_layout(G)
    pos = nx.get_node_attributes(G, 'pos')

    # Plot the graph
    plt.figure(figsize=(8, 8))
    nx.draw(
        G,
        pos,
        with_labels=True,
        node_color="skyblue",
        edge_color="gray",
        node_size=200,
        font_size=8,
        font_weight="bold",
        arrowsize=10,  # Arrow size
    )
    plt.title("Optimal TSP Path", fontsize=16)
    plt.show()
# Out:
# Optimal path:
# JFK -> TIP, TIP -> BEY, BEY -> KBL, KBL -> ISB, ISB -> FRU, FRU -> ALA, ALA -> SGN, SGN -> ADD, ADD -> KRT, KRT -> JUB, JUB -> EBB, EBB -> KGL, KGL -> BJM, BJM -> NBO, NBO -> DAR, DAR -> LLW, LLW -> LUN, LUN -> HRE, HRE -> MPM, MPM -> SHO, SHO -> MSU, MSU -> JNB, JNB -> GBE, GBE -> WDH, WDH -> LAD, LAD -> FIH, FIH -> DLA, DLA -> LOS, LOS -> COO, COO -> LFW, LFW -> ACC, ACC -> ABJ, ABJ -> OUA, OUA -> BKO, BKO -> ROB, ROB -> FNA, FNA -> CKY, CKY -> DSS, DSS -> GEO, GEO -> JBQ, JBQ -> PAP, PAP -> BZE, BZE -> GUA, GUA -> LAX

# %%
#Check if every node is visited once
def time_check(airport):
    count = ordered_path_str.count(airport)
    if airport == "JFK" or airport == "LAX":
        if count == 1:
            return True
    else:
        if count ==2:
            return True

if all(time_check(i) for i in airport_codes):
    print('Every node is visited once!')
# Out:
# Every node is visited once!

# %%
#Check if there is subtours
if model_pb1.status == grb.GRB.OPTIMAL:
    solution = model_pb1.getAttr("X", x_vars)
    if not find_subtours(solution, n):
        print("No subtour found!")
# Out:
# No subtour found!

# %% [markdown]
# # Problem 2: The Problem of Optimizing Splitted Shipment

# %% [markdown]
# ## Cases where all two planes are used

# %% [markdown]
# ### Transform mTSP to TSP

# %% [markdown]
# The two salesman problem is solved by transforming it into one traveling salesman problem. The transformation is based on https://doi.org/10.1016/0377-2217(94)00011-Z.

# %%
airport_codes_transformed = airport_codes + ["JFK_i", "LAX_i"]

distance_matrix_df_transformed = distance_matrix_df.copy()
distance_matrix_df_transformed["JFK_i"] = distance_matrix_df_transformed["JFK"]
distance_matrix_df_transformed["LAX_i"] = distance_matrix_df_transformed["LAX"]
distance_matrix_df_transformed.loc["JFK_i"] = distance_matrix_df_transformed.loc["JFK"]
distance_matrix_df_transformed.loc["LAX_i"] = distance_matrix_df_transformed.loc["LAX"]

# Distance from imaginary to next imaginary is 0
distance_matrix_df_transformed["JFK_i"]["LAX_i"] = 0

# Distance from imaginary to next depot is 0
distance_matrix_df_transformed["JFK_i"]["LAX"] = 0

# Distance from last imaginary to the first depot is 0
distance_matrix_df_transformed["LAX_i"]["JFK"] = 0

# %%
imaginary_edge_list = [("JFK_i", "LAX_i"), ("JFK_i", "LAX"), ("LAX_i", "JFK")]

# %%
distance_dict_transformed = distance_matrix_df_transformed.to_dict()

# %%
depot_nodes = ["JFK", "LAX"]
customer_nodes = [node for node in airport_codes if node not in depot_nodes]
imaginary_nodes = [f"{depot}_i" for depot in depot_nodes]

edge_list = []
# Add all edges between customers
for i in customer_nodes:
    for j in customer_nodes:
        if i != j:
            edge_list.append((i, j))

# Add all edges between depots and customers (in both directions)
for i in depot_nodes:
    for j in customer_nodes:
        edge_list.append((i, j))
        edge_list.append((j, i))
        
# Add all edges from customers to imaginary nodes
for i in customer_nodes:
    for j in imaginary_nodes:
        edge_list.append((i, j))

# Add edge from imaginary node to the next imaginary node
edge_list.append(("JFK_i", "LAX_i"))

# Add edge from imaginary node to the next depot
edge_list.append(("JFK_i", "LAX"))

# Add edge from last imaginary node to the first depot
edge_list.append(("LAX_i", "JFK"))

# %%
# Convert the edge list to a dictionary 
edges_out_dict = defaultdict(list)
edges_in_dict = defaultdict(list)
for i, j in edge_list:
    edges_out_dict[i].append(j)
    edges_in_dict[j].append(i)

# %%
nodes_list = list(edges_out_dict.keys())

# %%
# def solve_transformed_TSP(depot_nodes, customer_nodes, imaginary_nodes, edge_list, distance_dict):
TSP = grb.Model("TSP")

#Define the binary variable x between each pair of airports to decide whether the arcs between exists
x_vars = TSP.addVars(
    edge_list,
    lb=0,             
    vtype=grb.GRB.BINARY,  
    name="x"          
)

#Each node is arrived and departed only once
for i in edges_out_dict:
    departure_sum = grb.quicksum(x_vars[(i,j)] for j in edges_out_dict[i])
    TSP.addConstr(departure_sum == 1, name = "departed only once")
    
for i in edges_in_dict:
    arrival_sum = grb.quicksum(x_vars[(j,i)] for j in edges_in_dict[i])
    TSP.addConstr(arrival_sum == 1, name = "arrived only once")

#Set objective
total_distance = grb.quicksum((x_vars[(i,j)] * distance_matrix_df_transformed[i][j]) 
                    for i, j in edge_list
                    )
TSP.setObjective(total_distance, grb.GRB.MINIMIZE)
TSP.update()

# Initially optimize the model
TSP.optimize()

# Define a function to detect subtours
def find_subtours(solution, nodes_list):
    """
    Detect subtours in the solution.
    solution: The current solution used to construct the path graph.
    Returns: A list of subtours, where each subtour is a set of nodes.
    """
    n_nodes = len(nodes_list)
    
    # Build an adjacency list
    graph = defaultdict(list)
    for i, j in edge_list:
        if solution[i, j] > 0.5:  # Selected paths
            graph[i].append(j)

    # Use Depth First Search (DFS) to find all connected components
    visited = {code: False for code in nodes_list}
    subtours = []

    def dfs(node, current_tour):
        visited[node] = True
        current_tour.append(node)
        for neighbor in graph[node]:
            if not visited[neighbor]:
                dfs(neighbor, current_tour)

    for airport in nodes_list:
        if not visited[airport]:
            current_tour = []
            dfs(airport, current_tour)
            if 2 <= len(current_tour) <= n_nodes - 1:  # Exclude single-node loops and the whole tour
                subtours.append(current_tour)

    return subtours

# Dynamically add subtour elimination constraints
while True:
    # Get the current solution
    solution = TSP.getAttr("X", x_vars)

    # Check if there are any subtours
    subtours = find_subtours(solution, nodes_list)

    # Termination condition 1: No subtours, optimal solution found
    if not subtours:
        print("Optimal solution found")
        break

    # Add subtour elimination constraints
    for subtour in subtours:
        # Construct subtour constraints
        if len(subtour) > 1:
            TSP.addConstr(
                grb.quicksum(
                    x_vars[i, j]
                    for i in subtour 
                    for j in subtour 
                    if (i, j) in edge_list
                ) <= len(subtour) - 1
            )

    # Re-optimize the model
    TSP.optimize()
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 94 rows, 2067 columns and 4134 nonzeros
# Model fingerprint: 0x94c882ec
# Variable types: 0 continuous, 2067 integer (2067 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 250704.03578
# Presolve removed 4 rows and 89 columns
# Presolve time: 0.01s
# Presolved: 90 rows, 1978 columns, 3956 nonzeros
# Variable types: 0 continuous, 1978 integer (1978 binary)
#
# Root relaxation: objective 4.622124e+04, 70 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    46221.237967 46221.2380  0.00%     -    0s
#
# Explored 1 nodes (70 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 2: 46221.2 250704
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.622123796740e+04, best bound 4.622123796740e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 114 rows, 2067 columns and 4207 nonzeros
# Model fingerprint: 0xca831d02
# Variable types: 0 continuous, 2067 integer (2067 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R94 by 1.000000000
#
# Found heuristic solution: objective 250704.03578
# Presolve removed 4 rows and 89 columns
# Presolve time: 0.01s
# Presolved: 110 rows, 1978 columns, 4020 nonzeros
# Variable types: 0 continuous, 1978 integer (1978 binary)
#
# Root relaxation: objective 5.125597e+04, 117 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 51255.9704    0   20 250704.036 51255.9704  79.6%     -    0s
# H    0     0                    52011.674483 51255.9704  1.45%     -    0s
# H    0     0                    52007.990561 51255.9704  1.45%     -    0s
# H    0     0                    52007.011530 51255.9704  1.44%     -    0s
#      0     0 51255.9704    0   26 52007.0115 51255.9704  1.44%     -    0s
#      0     0 51255.9704    0   20 52007.0115 51255.9704  1.44%     -    0s
# H    0     0                    51881.865822 51255.9704  1.21%     -    0s
# H    0     0                    51400.604513 51255.9704  0.28%     -    0s
#      0     0 51265.7929    0   26 51400.6045 51265.7929  0.26%     -    0s
#      0     0 51265.7929    0   14 51400.6045 51265.7929  0.26%     -    0s
#      0     0 51291.4804    0   19 51400.6045 51291.4804  0.21%     -    0s
# H    0     0                    51298.205675 51291.4804  0.01%     -    0s
#
# Cutting planes:
#   Mod-K: 5
#
# Explored 1 nodes (265 simplex iterations) in 0.06 seconds (0.03 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 9: 51298.2 51400.6 51881.9 ... 250704
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.129820567481e+04, best bound 5.129820567481e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 120 rows, 2067 columns and 5117 nonzeros
# Model fingerprint: 0x72064464
# Variable types: 0 continuous, 2067 integer (2067 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R114 by 1.000000000
#
# Found heuristic solution: objective 250704.03578
# Presolve removed 3 rows and 45 columns
# Presolve time: 0.01s
# Presolved: 117 rows, 2022 columns, 5017 nonzeros
# Variable types: 0 continuous, 2022 integer (2022 binary)
#
# Root relaxation: objective 5.145831e+04, 128 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 51458.3051    0   26 250704.036 51458.3051  79.5%     -    0s
# H    0     0                    51585.673689 51458.3051  0.25%     -    0s
# H    0     0                    51483.274852 51458.3051  0.05%     -    0s
#
# Cutting planes:
#   Zero half: 1
#
# Explored 1 nodes (137 simplex iterations) in 0.04 seconds (0.02 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 3: 51483.3 51585.7 250704
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.148327485163e+04, best bound 5.148327485163e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 123 rows, 2067 columns and 6246 nonzeros
# Model fingerprint: 0x295d094e
# Variable types: 0 continuous, 2067 integer (2067 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R120 by 1.000000000
#
# Found heuristic solution: objective 250704.03578
# Presolve removed 3 rows and 45 columns
# Presolve time: 0.01s
# Presolved: 120 rows, 2022 columns, 6138 nonzeros
# Variable types: 0 continuous, 2022 integer (2022 binary)
#
# Root relaxation: objective 5.985493e+04, 131 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 59854.9257    0   32 250704.036 59854.9257  76.1%     -    0s
# H    0     0                    60767.397799 59854.9257  1.50%     -    0s
# H    0     0                    60606.274687 59854.9257  1.24%     -    0s
#      0     0 59854.9257    0   38 60606.2747 59854.9257  1.24%     -    0s
#      0     0 59854.9257    0   32 60606.2747 59854.9257  1.24%     -    0s
#      0     0 59921.0258    0   46 60606.2747 59921.0258  1.13%     -    0s
# H    0     0                    60100.936847 59921.0258  0.30%     -    0s
# H    0     0                    60022.813028 59921.0258  0.17%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Zero half: 6
#
# Explored 1 nodes (266 simplex iterations) in 0.06 seconds (0.03 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 7: 60022.8 60100.9 60606.3 ... 250704
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.002281302753e+04, best bound 6.002281302753e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 136 rows, 2067 columns and 6405 nonzeros
# Model fingerprint: 0xf95d203f
# Variable types: 0 continuous, 2067 integer (2067 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R123 by 1.000000000
#
# Found heuristic solution: objective 250704.03578
# Presolve removed 3 rows and 45 columns
# Presolve time: 0.01s
# Presolved: 133 rows, 2022 columns, 6290 nonzeros
# Variable types: 0 continuous, 2022 integer (2022 binary)
#
# Root relaxation: objective 6.074611e+04, 148 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    60746.105219 60746.1052  0.00%     -    0s
#
# Explored 1 nodes (148 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 2: 60746.1 250704
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.074610521868e+04, best bound 6.074610521868e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 138 rows, 2067 columns and 7992 nonzeros
# Model fingerprint: 0x5a6397de
# Variable types: 0 continuous, 2067 integer (2067 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R136 by 1.000000000
#
# Found heuristic solution: objective 250704.03578
# Presolve removed 3 rows and 45 columns
# Presolve time: 0.01s
# Presolved: 135 rows, 2022 columns, 7837 nonzeros
# Variable types: 0 continuous, 2022 integer (2022 binary)
#
# Root relaxation: objective 6.079448e+04, 159 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 60794.4765    0   86 250704.036 60794.4765  75.8%     -    0s
# H    0     0                    67308.898277 60794.4765  9.68%     -    0s
# H    0     0                    66479.164384 60794.4765  8.55%     -    0s
# H    0     0                    61393.401277 60794.4765  0.98%     -    0s
#      0     0 60794.4765    0   87 61393.4013 60794.4765  0.98%     -    0s
#      0     0 60794.4765    0   79 61393.4013 60794.4765  0.98%     -    0s
# H    0     0                    61180.718697 60794.4765  0.63%     -    0s
# H    0     0                    61091.846465 60794.4765  0.49%     -    0s
#
# Cutting planes:
#   Gomory: 1
#
# Explored 1 nodes (333 simplex iterations) in 0.07 seconds (0.05 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 7: 61091.8 61180.7 61393.4 ... 250704
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.109184646480e+04, best bound 6.109184646480e+04, gap 0.0000%
# Optimal solution found

# %%
# Collect the optimal path
optimal_path = {}
for i, j in edge_list:
    if x_vars[i, j].x > 0.5:
        if (i, j) not in imaginary_edge_list:
            optimal_path[i] = j

# Use NetworkX to draw the path graph
G = nx.DiGraph()  # Create a directed graph
# for i in airport_codes_transformed:
#     G.add_node(i, pos=(airports_df_transformed.loc[i, 'longitude_deg'], airports_df_transformed.loc[i, 'latitude_deg']))
G.add_edges_from([(i, j) for i, j in optimal_path.items()])

# Use circular layout for visualization
pos = nx.circular_layout(G)

# Plot the graph
plt.figure(figsize=(8, 8))
nx.draw(
    G,
    pos,
    with_labels=True,
    node_color="skyblue",
    edge_color="gray",
    node_size=200,
    font_size=8,
    font_weight="bold",
    arrowsize=10,  # Arrow size
)
plt.title("Optimal TSP Path", fontsize=16)
plt.show()

# %%
# Contract imaginary nodes
M = nx.contracted_nodes(G, "LAX", "LAX_i", self_loops=False)
M = nx.contracted_nodes(M, "JFK", "JFK_i", self_loops=False)

# %%
# Use circular layout for visualization
pos = nx.circular_layout(M)

# Plot the graph
plt.figure(figsize=(8, 8))
nx.draw(
    M,
    pos,
    with_labels=True,
    node_color="skyblue",
    edge_color="gray",
    node_size=200,
    font_size=8,
    font_weight="bold",
    arrowsize=10,  # Arrow size
)
plt.title("Optimal TSP Path", fontsize=16)
plt.show()

# %%
# Add positions to the graph
pos = defaultdict(tuple)

for i in airport_codes:
    pos[i] = (airports_df.loc[i, 'longitude_deg'], airports_df.loc[i, 'latitude_deg'])
    
nx.set_node_attributes(M, pos, "pos")

# %%
# Plot the graph
plt.figure(figsize=(8, 8))
nx.draw(
    M,
    pos,
    with_labels=True,
    node_color="skyblue",
    edge_color="gray",
    node_size=200,
    font_size=8,
    font_weight="bold",
    arrowsize=10,  # Arrow size
)
plt.title("Optimal mTSP Path", fontsize=16)
plt.show()

# %%
current_airport = "JFK"
ordered_path_from_JFK = ['JFK']
while True:
    next_airport = optimal_path[current_airport]
    if next_airport == "JFK_i":
        next_airport = "JFK"
    ordered_path_from_JFK.append(next_airport)
    current_airport = next_airport
    if next_airport == "JFK":
        break
    
current_airport = "LAX"
ordered_path_from_LAX = ['LAX']
while True:
    next_airport = optimal_path[current_airport]
    if next_airport == "LAX_i":
        next_airport = "LAX"
    ordered_path_from_LAX.append(next_airport)
    current_airport = next_airport
    if next_airport == "LAX":
        break

print('Route for plane from JFK')
print(ordered_path_from_JFK)
print('Route for plane from LAX')
print(ordered_path_from_LAX)
# Out:
# Route for plane from JFK
# ['JFK', 'PAP', 'JBQ', 'GEO', 'DSS', 'CKY', 'FNA', 'ROB', 'BKO', 'OUA', 'ABJ', 'ACC', 'LFW', 'COO', 'LOS', 'DLA', 'FIH', 'LAD', 'WDH', 'GBE', 'JNB', 'MSU', 'SHO', 'MPM', 'HRE', 'LUN', 'LLW', 'DAR', 'NBO', 'BJM', 'KGL', 'EBB', 'JUB', 'KRT', 'ADD', 'SGN', 'ALA', 'FRU', 'ISB', 'KBL', 'BEY', 'TIP', 'JFK']
# Route for plane from LAX
# ['LAX', 'GUA', 'BZE', 'LAX']

# %%
# Find the connected components of M
connected_components = list(nx.weakly_connected_components(M))
print('Number of connected components: ', len(connected_components))
# Out:
# Number of connected components:  2

# %%
# Compute the total distance
total_distance = 0
for i, j in optimal_path.items():
    total_distance += distance_dict_transformed[i][j]
    
print(f"The total distance is {total_distance:.2f}")
# Out:
# The total distance is 61091.85

# %% [markdown]
# ## Case where one of the planes stay at the starting node

# %%
def solve_TSP(nodes_list, distance_dict):
    TSP = grb.Model("TSP")
    
    x_vars = TSP.addVars(
    nodes_list,
    nodes_list,
    lb=0,             
    vtype=grb.GRB.BINARY,  
    name="x"          
    )
    
    #Each node is arrived and departed only once (except the starting and the ending point)
    for i in nodes_list:
        departure_sum = grb.quicksum(x_vars[(i,j)] for j in nodes_list if i != j)
        arrival_sum = grb.quicksum(x_vars[(j,i)] for j in nodes_list if i != j)

        TSP.addConstr(departure_sum == 1, name = "departed only once")
        TSP.addConstr(arrival_sum == 1, name = "arrived only once")

    # Route x_ii == 0
    for i in nodes_list:
        TSP.addConstr((x_vars[(i,i)]) == 0) 
        
    #Set objective
    total_distance = grb.quicksum((x_vars[(i,j)] * distance_dict[i,j]) 
                        for i in nodes_list
                        for j in nodes_list 
                        )
    TSP.setObjective(total_distance, grb.GRB.MINIMIZE)
    TSP.update()
    
    # Initially optimize the model
    TSP.optimize()

    # Define a function to detect subtours
    def find_subtours(solution):
        """
        Detect subtours in the solution.
        solution: The current solution used to construct the path graph.
        Returns: A list of subtours, where each subtour is a set of nodes.
        """
        
        n_nodes = len(nodes_list)
        
        # Build an adjacency list
        graph = defaultdict(list)
        for i in nodes_list:
            for j in nodes_list:
                if solution[i, j] > 0.5:  # Selected paths
                    graph[i].append(j)

        # Use Depth First Search (DFS) to find all connected components
        visited = {code: False for code in nodes_list}
        subtours = []

        def dfs(node, current_tour):
            visited[node] = True
            current_tour.append(node)
            for neighbor in graph[node]:
                if not visited[neighbor]:
                    dfs(neighbor, current_tour)

        for airport in nodes_list:
            if not visited[airport]:
                current_tour = []
                dfs(airport, current_tour)
                if 2 <= len(current_tour) <= n_nodes - 1:  # Exclude single-node loops and the whole tour
                    subtours.append(current_tour)

        return subtours

    # Dynamically add subtour elimination constraints
    while True:
        # Get the current solution
        solution = TSP.getAttr("X", x_vars)

        # Check if there are any subtours
        subtours = find_subtours(solution)

        # Termination condition 1: No subtours, optimal solution found
        if not subtours:
            print("Optimal solution found")
            break

        # Add subtour elimination constraints
        for subtour in subtours:
            # Construct subtour constraints
            if len(subtour) > 1:
                TSP.addConstr(
                    grb.quicksum(
                        x_vars[i, j]
                        for i in subtour for j in subtour if i != j
                    ) <= len(subtour) - 1
                )

        # Re-optimize the model
        TSP.optimize()
        
    # Output the final path
    if TSP.status == grb.GRB.OPTIMAL:
        
        optimal_path = {}
        for i in nodes_list:
            for j in nodes_list:
                if x_vars[i, j].x > 0.5:
                    optimal_path[i] = j
        
        print("Optimal solution found")
        return TSP, optimal_path
    
    else:
        print("No optimal solution found")
        raise Exception("No optimal solution found")

# %%
# Consider the case where the plane starts from JFK stays at JFK
airport_codes_without_JFK = airport_codes.copy()
airport_codes_without_JFK.remove("JFK")

TSP_without_JFK, TSP_without_JFK_path = solve_TSP(airport_codes_without_JFK, distance_dict)
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 132 rows, 1936 columns and 3828 nonzeros
# Model fingerprint: 0xaf9e3a06
# Variable types: 0 continuous, 1936 integer (1936 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 275028.57873
# Presolve removed 44 rows and 44 columns
# Presolve time: 0.00s
# Presolved: 88 rows, 1892 columns, 3784 nonzeros
# Variable types: 0 continuous, 1892 integer (1892 binary)
#
# Root relaxation: objective 4.173052e+04, 78 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    41730.515901 41730.5159  0.00%     -    0s
#
# Explored 1 nodes (78 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 2: 41730.5 275029
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.173051590132e+04, best bound 4.173051590132e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 152 rows, 1936 columns and 3884 nonzeros
# Model fingerprint: 0x81031679
# Variable types: 0 continuous, 1936 integer (1936 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R132 by 1.000000000
#
# Found heuristic solution: objective 275028.57873
# Presolve removed 44 rows and 44 columns
# Presolve time: 0.01s
# Presolved: 108 rows, 1892 columns, 3840 nonzeros
# Variable types: 0 continuous, 1892 integer (1892 binary)
#
# Root relaxation: objective 4.932250e+04, 126 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 49322.4998    0   20 275028.579 49322.4998  82.1%     -    0s
# H    0     0                    50342.160906 49322.4998  2.03%     -    0s
# H    0     0                    50178.729489 49322.4998  1.71%     -    0s
# H    0     0                    50081.545663 49322.4998  1.52%     -    0s
#      0     0 49322.4998    0   26 50081.5457 49322.4998  1.52%     -    0s
#      0     0 49322.4998    0   20 50081.5457 49322.4998  1.52%     -    0s
# H    0     0                    50074.519965 49322.4998  1.50%     -    0s
# H    0     0                    50073.540933 49322.4998  1.50%     -    0s
# H    0     0                    49467.133916 49329.2251  0.28%     -    0s
#      0     0 49336.5782    0   26 49467.1339 49336.5782  0.26%     -    0s
# H    0     0                    49364.735078 49336.5782  0.06%     -    0s
#      0     0 49354.5395    0   32 49364.7351 49354.5395  0.02%     -    0s
#
# Cutting planes:
#   Mod-K: 2
#
# Explored 1 nodes (237 simplex iterations) in 0.04 seconds (0.03 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 10: 49364.7 49467.1 50073.5 ... 275029
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.936473507789e+04, best bound 4.936473507789e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 159 rows, 1936 columns and 4774 nonzeros
# Model fingerprint: 0xee99215c
# Variable types: 0 continuous, 1936 integer (1936 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R152 by 1.000000000
#
# Found heuristic solution: objective 275028.57873
# Presolve removed 44 rows and 44 columns
# Presolve time: 0.01s
# Presolved: 115 rows, 1892 columns, 4730 nonzeros
# Variable types: 0 continuous, 1892 integer (1892 binary)
#
# Root relaxation: objective 4.974361e+04, 132 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 49743.6113    0   30 275028.579 49743.6113  81.9%     -    0s
# H    0     0                    49870.979903 49743.6113  0.26%     -    0s
#      0     0 49743.6113    0   36 49870.9799 49743.6113  0.26%     -    0s
# H    0     0                    49768.581066 49743.6113  0.05%     -    0s
#      0     0     cutoff    0      49768.5811 49768.5811  0.00%     -    0s
#
# Explored 1 nodes (151 simplex iterations) in 0.05 seconds (0.03 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 3: 49768.6 49871 275029
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.976858106572e+04, best bound 4.976858106572e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 162 rows, 1936 columns and 5880 nonzeros
# Model fingerprint: 0x5272f8e0
# Variable types: 0 continuous, 1936 integer (1936 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R159 by 1.000000000
#
# Found heuristic solution: objective 275028.57873
# Presolve removed 44 rows and 44 columns
# Presolve time: 0.01s
# Presolved: 118 rows, 1892 columns, 5836 nonzeros
# Variable types: 0 continuous, 1892 integer (1892 binary)
#
# Root relaxation: objective 5.749126e+04, 161 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 57491.2551    0   70 275028.579 57491.2551  79.1%     -    0s
# H    0     0                    69828.489814 57491.2551  17.7%     -    0s
# H    0     0                    69569.982430 57491.2551  17.4%     -    0s
#      0     0 57491.2551    0   84 69569.9824 57491.2551  17.4%     -    0s
# H    0     0                    61640.011926 57491.2551  6.73%     -    0s
# H    0     0                    59154.671840 57491.2551  2.81%     -    0s
# H    0     0                    57498.469933 57491.2551  0.01%     -    0s
#
# Cutting planes:
#   Zero half: 4
#
# Explored 1 nodes (184 simplex iterations) in 0.05 seconds (0.04 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 6: 57498.5 59154.7 61640 ... 275029
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.749846993344e+04, best bound 5.749846993344e+04, gap 0.0000%
# Optimal solution found
# Optimal solution found

# %%
# print the objective value
print("Objective value of TSP without JFK: ", TSP_without_JFK.ObjVal)
# Out:
# Objective value of TSP without JFK:  57498.46993344373

# %%
G = nx.DiGraph()  # Create a directed graph
for i in airport_codes:
    G.add_node(i, pos=(airports_df.loc[i, 'longitude_deg'], airports_df.loc[i, 'latitude_deg']))
G.add_edges_from([(i, j) for i, j in TSP_without_JFK_path.items()])

pos = nx.get_node_attributes(G, 'pos')

# Plot the graph
plt.figure(figsize=(8, 8))
nx.draw(
    G,
    pos,
    with_labels=True,
    node_color="skyblue",
    edge_color="gray",
    node_size=200,
    font_size=8,
    font_weight="bold",
    arrowsize=10,  # Arrow size
)
plt.title("Optimal TSP Path", fontsize=16)
plt.show()

# %%
current_airport = "LAX"
ordered_path_from_LAX = ['LAX']
while True:
    next_airport = TSP_without_JFK_path[current_airport]
    ordered_path_from_LAX.append(next_airport)
    current_airport = next_airport
    if next_airport == "LAX":
        break
    
print('Route for plane from LAX')
print(ordered_path_from_LAX)
# Out:
# Route for plane from LAX
# ['LAX', 'GUA', 'BZE', 'PAP', 'JBQ', 'GEO', 'DSS', 'CKY', 'FNA', 'ROB', 'BKO', 'OUA', 'ABJ', 'ACC', 'LFW', 'COO', 'LOS', 'DLA', 'FIH', 'LAD', 'WDH', 'GBE', 'JNB', 'MSU', 'SHO', 'MPM', 'HRE', 'LUN', 'LLW', 'DAR', 'NBO', 'BJM', 'KGL', 'EBB', 'JUB', 'ADD', 'KRT', 'TIP', 'BEY', 'KBL', 'ISB', 'FRU', 'ALA', 'SGN', 'LAX']

# %%
# Consider the case where the plane starts from LAX stays at LAX
airport_codes_without_LAX = airport_codes.copy()
airport_codes_without_LAX.remove("LAX")

TSP_without_LAX, TSP_without_LAX_path = solve_TSP(airport_codes_without_LAX, distance_dict)
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 132 rows, 1936 columns and 3828 nonzeros
# Model fingerprint: 0x7f354f89
# Variable types: 0 continuous, 1936 integer (1936 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 267205.07258
# Presolve removed 44 rows and 44 columns
# Presolve time: 0.01s
# Presolved: 88 rows, 1892 columns, 3784 nonzeros
# Variable types: 0 continuous, 1892 integer (1892 binary)
#
# Root relaxation: objective 3.959223e+04, 77 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    39592.233996 39592.2340  0.00%     -    0s
#
# Explored 1 nodes (77 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 2: 39592.2 267205
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.959223399575e+04, best bound 3.959223399575e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 153 rows, 1936 columns and 3878 nonzeros
# Model fingerprint: 0x596a66a4
# Variable types: 0 continuous, 1936 integer (1936 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R132 by 1.000000000
#
# Found heuristic solution: objective 267205.07258
# Presolve removed 44 rows and 44 columns
# Presolve time: 0.01s
# Presolved: 109 rows, 1892 columns, 3834 nonzeros
# Variable types: 0 continuous, 1892 integer (1892 binary)
#
# Root relaxation: objective 4.593762e+04, 118 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 45937.6249    0   20 267205.073 45937.6249  82.8%     -    0s
# H    0     0                    48775.590108 45937.6249  5.82%     -    0s
# H    0     0                    48435.615343 45937.6249  5.16%     -    0s
# H    0     0                    47310.905994 45937.6249  2.90%     -    0s
# H    0     0                    46515.868231 45937.6249  1.24%     -    0s
#      0     0 45937.6249    0   24 46515.8682 45937.6249  1.24%     -    0s
#      0     0 45937.6249    0   20 46515.8682 45937.6249  1.24%     -    0s
# H    0     0                    46393.329986 45937.6249  0.98%     -    0s
# H    0     0                    46083.238004 45937.6249  0.32%     -    0s
# H    0     0                    46082.258972 45937.6249  0.31%     -    0s
#      0     0 45951.7033    0   26 46082.2590 45951.7033  0.28%     -    0s
#      0     0 45951.7033    0   14 46082.2590 45951.7033  0.28%     -    0s
# H    0     0                    45979.860135 45951.7033  0.06%     -    0s
#      0     0 45965.9586    0   19 45979.8601 45965.9586  0.03%     -    0s
#
# Cutting planes:
#   Mod-K: 5
#
# Explored 1 nodes (271 simplex iterations) in 0.06 seconds (0.03 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 10: 45979.9 46082.3 46083.2 ... 267205
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.597986013451e+04, best bound 4.597986013451e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 159 rows, 1936 columns and 4774 nonzeros
# Model fingerprint: 0x35f7f63e
# Variable types: 0 continuous, 1936 integer (1936 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R153 by 1.000000000
#
# Found heuristic solution: objective 267205.07258
# Presolve removed 44 rows and 44 columns
# Presolve time: 0.01s
# Presolved: 115 rows, 1892 columns, 4730 nonzeros
# Variable types: 0 continuous, 1892 integer (1892 binary)
#
# Root relaxation: objective 4.688093e+04, 126 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 46880.9269    0   26 267205.073 46880.9269  82.5%     -    0s
# H    0     0                    47008.295563 46880.9269  0.27%     -    0s
# H    0     0                    46905.896725 46880.9269  0.05%     -    0s
#      0     0 46880.9269    0   73 46905.8967 46880.9269  0.05%     -    0s
#
# Cutting planes:
#   Zero half: 2
#
# Explored 1 nodes (147 simplex iterations) in 0.05 seconds (0.03 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 3: 46905.9 47008.3 267205
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.690589672504e+04, best bound 4.690589672504e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 162 rows, 1936 columns and 5880 nonzeros
# Model fingerprint: 0x2e09f353
# Variable types: 0 continuous, 1936 integer (1936 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R159 by 1.000000000
#
# Found heuristic solution: objective 267205.07258
# Presolve removed 44 rows and 44 columns
# Presolve time: 0.01s
# Presolved: 118 rows, 1892 columns, 5836 nonzeros
# Variable types: 0 continuous, 1892 integer (1892 binary)
#
# Root relaxation: objective 5.527755e+04, 157 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 55277.5475    0   32 267205.073 55277.5475  79.3%     -    0s
# H    0     0                    56190.019672 55277.5475  1.62%     -    0s
# H    0     0                    56028.896561 55277.5475  1.34%     -    0s
#      0     0 55277.5475    0   38 56028.8966 55277.5475  1.34%     -    0s
#      0     0 55277.5475    0   32 56028.8966 55277.5475  1.34%     -    0s
#      0     0 55305.5972    0   62 56028.8966 55305.5972  1.29%     -    0s
# H    0     0                    55523.558721 55305.5972  0.39%     -    0s
# H    0     0                    55445.434901 55305.5972  0.25%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Zero half: 4
#
# Explored 1 nodes (292 simplex iterations) in 0.07 seconds (0.04 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 7: 55445.4 55523.6 56028.9 ... 267205
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.544543490093e+04, best bound 5.544543490093e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 175 rows, 1936 columns and 6020 nonzeros
# Model fingerprint: 0x14910f04
# Variable types: 0 continuous, 1936 integer (1936 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R162 by 1.000000000
#
# Found heuristic solution: objective 267205.07258
# Presolve removed 44 rows and 44 columns
# Presolve time: 0.01s
# Presolved: 131 rows, 1892 columns, 5976 nonzeros
# Variable types: 0 continuous, 1892 integer (1892 binary)
#
# Root relaxation: objective 5.616873e+04, 171 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    56168.727092 56168.7271  0.00%     -    0s
#
# Explored 1 nodes (171 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 2: 56168.7 267205
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.616872709208e+04, best bound 5.616872709208e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 177 rows, 1936 columns and 7456 nonzeros
# Model fingerprint: 0xbdd70108
# Variable types: 0 continuous, 1936 integer (1936 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R175 by 1.000000000
#
# Found heuristic solution: objective 267205.07258
# Presolve removed 44 rows and 44 columns
# Presolve time: 0.01s
# Presolved: 133 rows, 1892 columns, 7412 nonzeros
# Variable types: 0 continuous, 1892 integer (1892 binary)
#
# Root relaxation: objective 5.651447e+04, 195 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    56514.468338 56514.4683  0.00%     -    0s
#
# Explored 1 nodes (195 simplex iterations) in 0.03 seconds (0.02 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 2: 56514.5 267205
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.651446833821e+04, best bound 5.651446833821e+04, gap 0.0000%
# Optimal solution found
# Optimal solution found

# %%
# Print objective value
print("Objective value of TSP without LAX: ", TSP_without_LAX.ObjVal)
# Out:
# Objective value of TSP without LAX:  56514.46833820903

# %%
G = nx.DiGraph()  # Create a directed graph
for i in airport_codes:
    G.add_node(i, pos=(airports_df.loc[i, 'longitude_deg'], airports_df.loc[i, 'latitude_deg']))
G.add_edges_from([(i, j) for i, j in TSP_without_LAX_path.items()])

pos = nx.get_node_attributes(G, 'pos')

# Plot the graph
plt.figure(figsize=(8, 8))
nx.draw(
    G,
    pos,
    with_labels=True,
    node_color="skyblue",
    edge_color="gray",
    node_size=200,
    font_size=8,
    font_weight="bold",
    arrowsize=10,  # Arrow size
)
plt.title("Optimal TSP Path", fontsize=16)
plt.show()

# %%
current_airport = "JFK"
ordered_path_from_JFK = ['JFK']
while True:
    next_airport = TSP_without_LAX_path[current_airport]
    ordered_path_from_JFK.append(next_airport)
    current_airport = next_airport
    if next_airport == "JFK":
        break
    
print('Route for plane from JFK')
print(ordered_path_from_JFK)
# Out:
# Route for plane from JFK
# ['JFK', 'TIP', 'BEY', 'KBL', 'ISB', 'FRU', 'ALA', 'SGN', 'ADD', 'KRT', 'JUB', 'EBB', 'KGL', 'BJM', 'NBO', 'DAR', 'LLW', 'LUN', 'HRE', 'MPM', 'SHO', 'MSU', 'JNB', 'GBE', 'WDH', 'LAD', 'FIH', 'DLA', 'LOS', 'COO', 'LFW', 'ACC', 'ABJ', 'OUA', 'BKO', 'ROB', 'FNA', 'CKY', 'DSS', 'GEO', 'JBQ', 'PAP', 'GUA', 'BZE', 'JFK']
